# %%
import pandas as pd
# from datetime import datetime as dt
import matplotlib.pyplot as plt
# import seaborn as sns 
# sns.set(style="darkgrid")

# %%
def plot_figs(name_to_log_mapping, save_name=None):
    plt.figure(figsize=(20,10))
    for name, log in name_to_log_mapping.items():
        plt.plot(log['sys_time'], log['logical_time'], label=name+' logical', linewidth=1)
        plt.plot(log['sys_time'], log['queue_len'], label=name+' queue', linewidth=4, marker=".")
    plt.legend(loc="upper left")
#    plt.show()
    if save_name is not None:
        plt.savefig('figs/'+save_name+'.png')

# %%
runsig = '115'
logs = {
    'm0': pd.read_csv(f'logs/{runsig}machine0.csv', skiprows=1),
    'm1': pd.read_csv(f'logs/{runsig}machine1.csv', skiprows=1),
    'm2': pd.read_csv(f'logs/{runsig}machine2.csv', skiprows=1)
}
plot_figs(logs, save_name=runsig)

# %%
logs = {
    'm0': pd.read_csv('logs/122machine0.csv', skiprows=1),
    'm1': pd.read_csv('logs/122machine1.csv', skiprows=1),
    'm2': pd.read_csv('logs/122machine2.csv', skiprows=1)
}
plot_figs(logs, save_name='122')

# %%
logs = {
    'm0': pd.read_csv('logs/124machine0.csv', skiprows=1),
    'm1': pd.read_csv('logs/124machine1.csv', skiprows=1),
    'm2': pd.read_csv('logs/124machine2.csv', skiprows=1)
}
plot_figs(logs, save_name='124')

# %%
runsig = '136'
logs = {
    'm0': pd.read_csv(f'logs/{runsig}machine0.csv', skiprows=1),
    'm1': pd.read_csv(f'logs/{runsig}machine1.csv', skiprows=1),
    'm2': pd.read_csv(f'logs/{runsig}machine2.csv', skiprows=1)
}
plot_figs(logs, save_name=runsig)

# %%
runsig = '156'
logs = {
    'm0': pd.read_csv(f'logs/{runsig}machine0.csv', skiprows=1),
    'm1': pd.read_csv(f'logs/{runsig}machine1.csv', skiprows=1),
    'm2': pd.read_csv(f'logs/{runsig}machine2.csv', skiprows=1)
}
plot_figs(logs, save_name=runsig)

# %%
runsig = '235'
logs = {
    'm0': pd.read_csv(f'logs/{runsig}machine0.csv', skiprows=1),
    'm1': pd.read_csv(f'logs/{runsig}machine1.csv', skiprows=1),
    'm2': pd.read_csv(f'logs/{runsig}machine2.csv', skiprows=1)
}
plot_figs(logs, save_name=runsig)

# %%
logs = {
    'm0': pd.read_csv('logs/245machine0.csv', skiprows=1),
    'm1': pd.read_csv('logs/245machine1.csv', skiprows=1),
    'm2': pd.read_csv('logs/245machine2.csv', skiprows=1)
}
plot_figs(logs, save_name='245')

# %%
logs = {
    'm0': pd.read_csv('logs/266machine0.csv', skiprows=1),
    'm1': pd.read_csv('logs/266machine1.csv', skiprows=1),
    'm2': pd.read_csv('logs/266machine2.csv', skiprows=1)
}
plot_figs(logs, save_name='266')

# %%
logs = {
    'm0': pd.read_csv('logs/166machine0.csv', skiprows=1),
    'm1': pd.read_csv('logs/166machine1.csv', skiprows=1),
    'm2': pd.read_csv('logs/166machine2.csv', skiprows=1)
}
plot_figs(logs, save_name='166')

# %%
runsig = '555'
logs = {
    'm0': pd.read_csv(f'logs/{runsig}machine0.csv', skiprows=1),
    'm1': pd.read_csv(f'logs/{runsig}machine1.csv', skiprows=1),
    'm2': pd.read_csv(f'logs/{runsig}machine2.csv', skiprows=1)
}
plot_figs(logs, save_name=runsig)

# %%
runsig = '532_4maxrandint_'
logs = {
    'm0': pd.read_csv(f'logs/{runsig}machine0.csv', skiprows=1),
    'm1': pd.read_csv(f'logs/{runsig}machine1.csv', skiprows=1),
    'm2': pd.read_csv(f'logs/{runsig}machine2.csv', skiprows=1)
}
plot_figs(logs, save_name=runsig)

# %%
runsig = '34rest_20maxrandint_'
logs = {
    'm0': pd.read_csv(f'logs/{runsig}machine0.csv', skiprows=1),
    'm1': pd.read_csv(f'logs/{runsig}machine1.csv', skiprows=1),
    'm2': pd.read_csv(f'logs/{runsig}machine2.csv', skiprows=1),
    'm3': pd.read_csv(f'logs/{runsig}machine3.csv', skiprows=1),
    'm4': pd.read_csv(f'logs/{runsig}machine4.csv', skiprows=1),
    'm5': pd.read_csv(f'logs/{runsig}machine5.csv', skiprows=1),
    'm6': pd.read_csv(f'logs/{runsig}machine6.csv', skiprows=1),
    'm7': pd.read_csv(f'logs/{runsig}machine7.csv', skiprows=1),
    'm8': pd.read_csv(f'logs/{runsig}machine8.csv', skiprows=1),
    'm9': pd.read_csv(f'logs/{runsig}machine9.csv', skiprows=1),
    'm10': pd.read_csv(f'logs/{runsig}machine10.csv', skiprows=1),
    'm11': pd.read_csv(f'logs/{runsig}machine11.csv', skiprows=1)
}
plot_figs(logs, save_name=runsig)
